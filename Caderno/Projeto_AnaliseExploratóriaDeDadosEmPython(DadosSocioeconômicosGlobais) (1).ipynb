# %% [markdown]
# # Projeto Análise Exploratória: Dados Socioeconômicos Globais

# %% [markdown]
# ---

# %%
display(Image(url='https://www.new-social.com/wp-content/uploads/2018/12/Imagens-do-planeta-Terra-em-alta-resolu%C3%A7%C3%A3o-11.jpg',width=1075))
# Out:
# <img src="https://www.new-social.com/wp-content/uploads/2018/12/Imagens-do-planeta-Terra-em-alta-resolu%C3%A7%C3%A3o-11.jpg" width="1075"/>

# %% [markdown]
# ## Introdução

# %% [markdown]
# Para a realização desse projeto foram utilizados diferentes conjuntos de dados. Podemos com os bancos de dados, gerar visualizações relevantes sobre o histórico de crescimento populacional, comparação entre os dados e entender como anda o funcionamento socioeconômico global, dentre vários outros exemplos.
#
# >O **1ª conjunto de dados** foi encontrado no seguinte link: https://www.kaggle.com/datasets/rajkumarpandey02/2023-world-population-by-country ; e nos traz dados sobre a população mundial por país.
#
# >O **2ª conjunto de dados** utilizados para esse projeto foi encontrado no seguinte link: https://www.dadosmundiais.com/america/index.php ;  a seguintes base de dados nos traz valores socioeconômicos de dados sobre os países da América do Sul.
#
# >O **3ª conjunto de dados** foi retirado do seguinte site https://pt.wikipedia.org/wiki/Demografia_do_Brasil; e traz dados sobre a população brasileira em 2022 por Regiões, Estados e Municípios.
#
# >O **4ª conjunto de dados** foi retirado dos mesmo site do conjunto anterior https://pt.wikipedia.org/wiki/Demografia_do_Brasil; e traz dados sobre a população de 2022 de um pequeno grupo de países dividido por faixa etária.

# %% [markdown]
# **ATRIBUTOS:**

# %% [markdown]
# O **1ª conjunto de dados** possui os seguintes atributos:
#
#
# *   **place**: número do lugar;
# *   **pop1980**: população neste ano;
# *   **pop2000**: população neste ano;
# *   **pop2010**: população neste ano;
# *   **pop2022**: população neste ano;
# *   **pop2023**: população prevista para este ano;
# *   **pop2030**: população prevista para este ano;
# *   **pop2050**: população prevista para este ano;
# *   **country**: Nome do país;
# *   **area**: Área Por Km;
# *   **landAreaKm**: Área do terreno por km;
# *   **cca2**: valores únicos;
# *   **cca3**: valores únicos;
# *   **netChange**: Mudança de rede %;
# *   **growthRate**: Taxa de crescimento;
# *   **worldPercentage**: % de crescimento mundial;
# *   **density**: Densidade por Km;
# *   **densityMi**: densidade em milhas quadradas;
# *   **rank**: Classificação do país.

# %% [markdown]
# O **2ª Conjunto de dados** possui os seguintes atributos:
#
# *   **País**: nome do país correspondente;
# *   **PBI(bi R$)**: O produto interno bruto representa a soma de todos os bens e serviços finais produzidos numa determinada região, durante um período determinado;
# *   **Taxa de endividamento**: taxa de quanto o país está em dívida econômica;
# *   **Taxa de desemprego**: se refere a desocupação oficial no país;
# *   **Taxa de inflação**: é um aumento geral nos preços de bens e serviços em uma economia;
# *   **Índice de corrupção**:A escala varia de 0 a 100, sendo que quanto maior a pontuação, mais massiva a corrupção.

# %% [markdown]
# O **3ª Conjunto de dados** possui os seguintes atributos:
#
# *   **Região**: Refere-se as Regiões brasileiras, que são cinco: Norte, Nordeste, Centro-Oeste, Sudeste e Sul;
# *   **Estados**: Refere-se aos Estados do país referentes a sua Região;
# *   **Municípios**: Traz a quantidade de municípios por Região;
# *   **População(2022)[5]**: Traz a quantidade total de pessoas por região em 2022.

# %% [markdown]
# O **4ª Conjunto de dados** possui os seguintes atributos:
#
# *  **País**: refere-se a um pequeno grupo de países: Brasil, Reino Unido, México e Nigéria;
# *   **Crianças(de 0 a 14 anos)**: Traz a porcentagem de valores da população de crianças de determinado país;
# *   **Jovens(de 15 a 24 anos)**: Traz a porcentagem de valores da população jovem por país;
# *   **Adultos(de 25 a 64 anos)**: Traz a porcantagem de valores de da população de adultos por país;
# *   **Idosos(a partir de 65 anos)**: Traz a porcentagem de valores da população idosa de acordo com o país.

# %% [markdown]
# ---

# %% [markdown]
# ## 1ª CONJUNTO DE DADOS (Países)

# %%
display(Image(url='https://static.vecteezy.com/ti/vetor-gratis/p1/20833849-mundo-mapa-com-pais-nomes-gratis-vetor.jpg',width=1075))
# Out:
# <img src="https://static.vecteezy.com/ti/vetor-gratis/p1/20833849-mundo-mapa-com-pais-nomes-gratis-vetor.jpg" width="1075"/>

# %% [markdown]
# ### Preparando os dados para o projeto:

# %% [markdown]
# **importando os dados**

# %%
from IPython.display import Image, display
import json
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px

# %%
# !wget -q "https://storage.googleapis.com/kagglesdsdata/datasets/3346108/5822810/countries-table.json?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230902%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230902T123929Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=..." -O paises.json

# %%
with open('paises.json', mode='r', encoding='utf8') as file:
  data = json.load(file)

# %%
len(data)
# Out:
# 234

# %% [markdown]
#   **Explorando o conjunto de dados do 1ª exemplo**

# %%
example = data[0]
print(example.keys())
# Out:
# dict_keys(['place', 'pop1980', 'pop2000', 'pop2010', 'pop2022', 'pop2023', 'pop2030', 'pop2050', 'country', 'area', 'landAreaKm', 'cca2', 'cca3', 'netChange', 'growthRate', 'worldPercentage', 'density', 'densityMi', 'rank'])

# %%
example['place']
# Out:
# 356

# %%
example['pop1980']
# Out:
# 696828385

# %%
example['pop2000']
# Out:
# 1059633675

# %%
example['pop2010']
# Out:
# 1240613620

# %%
example['pop2022']
# Out:
# 1417173173

# %%
example['pop2023']
# Out:
# 1428627663

# %%
example['pop2030']
# Out:
# 1514994080

# %%
example['pop2050']
# Out:
# 1670490596

# %%
example['country']
# Out:
# 'India'

# %%
example['area']
# Out:
# 3287590

# %%
example['landAreaKm']
# Out:
# 2973190

# %%
example['cca2']
# Out:
# 'IN'

# %%
example['cca3']
# Out:
# 'IND'

# %%
example['netChange']
# Out:
# 0.4184

# %%
example['growthRate']
# Out:
# 0.0081

# %%
example['density']
# Out:
# 480.5033

# %%
example['densityMi']
# Out:
# 1244.5036

# %%
example['rank']
# Out:
# 1

# %% [markdown]
# Acima verificamos os dados da 1ª linha. Podemos notar que estão todos corretos e seguindo a ordem desejada.

# %% [markdown]
# **Vizualizando os dados para entender a estrutura dos dados**

# %%
paises_df = pd.DataFrame(data)
paises_df.head()
# Out:
#    place      pop1980       pop2000       pop2010       pop2022       pop2023  \
# 0    356  696828385.0  1.059634e+09  1.240614e+09  1.417173e+09  1.428628e+09
# 1    156  982372466.0  1.264099e+09  1.348191e+09  1.425887e+09  1.425671e+09
# 2    840  223140018.0  2.823986e+08  3.111828e+08  3.382899e+08  3.399966e+08
# 3    360  148177096.0  2.140724e+08  2.440162e+08  2.755013e+08  2.775341e+08
# 4    586   80624057.0  1.543699e+08  1.944545e+08  2.358249e+08  2.404857e+08
#
#         pop2030       pop2050        country       area  landAreaKm cca2 cca3  \
# 0  1.514994e+09  1.670491e+09          India  3287590.0   2973190.0   IN  IND
# 1  1.415606e+09  1.312636e+09          China  9706961.0   9424702.9   CN  CHN
# 2  3.521623e+08  3.753920e+08  United States  9372610.0   9147420.0   US  USA
# 3  2.921501e+08  3.172252e+08      Indonesia  1904569.0   1877519.0   ID  IDN
# 4  2.740298e+08  3.678085e+08       Pakistan   881912.0    770880.0   PK  PAK
#
# ...

# %%
paises_df.shape
# Out:
# (234, 19)

# %%
paises_df.columns
# Out:
# Index(['place', 'pop1980', 'pop2000', 'pop2010', 'pop2022', 'pop2023',
#        'pop2030', 'pop2050', 'country', 'area', 'landAreaKm', 'cca2', 'cca3',
#        'netChange', 'growthRate', 'worldPercentage', 'density', 'densityMi',
#        'rank'],
#       dtype='object')

# %%
paises_df.index
# Out:
# RangeIndex(start=0, stop=234, step=1)

# %%
paises_df.info
# Out:
# <bound method DataFrame.info of      place      pop1980       pop2000       pop2010       pop2022  \
# 0      356  696828385.0  1.059634e+09  1.240614e+09  1.417173e+09
# 1      156  982372466.0  1.264099e+09  1.348191e+09  1.425887e+09
# 2      840  223140018.0  2.823986e+08  3.111828e+08  3.382899e+08
# 3      360  148177096.0  2.140724e+08  2.440162e+08  2.755013e+08
# 4      586   80624057.0  1.543699e+08  1.944545e+08  2.358249e+08
# ..     ...          ...           ...           ...           ...
# 229    500      11452.0  5.138000e+03  4.938000e+03  4.390000e+03
# 230    238       2240.0  3.080000e+03  3.187000e+03  3.780000e+03
# 231    570       3637.0  2.074000e+03  1.812000e+03  1.934000e+03
# 232    772       1647.0  1.666000e+03  1.367000e+03  1.871000e+03
# 233    336        733.0  6.510000e+02  5.960000e+02  5.100000e+02
#
#           pop2023       pop2030       pop2050           country        area  \
# ...

# %% [markdown]
# **SCHEMA**

# %% [markdown]
# Atributos categóricos:

# %%
paises_df.select_dtypes("object").describe().transpose()
# Out:
#         count unique    top freq
# country   234    234  India    1
# cca2      234    234     IN    1
# cca3      234    234    IND    1

# %% [markdown]
# Atributos numéricos:

# %%
paises_df.drop(["country","cca2","cca3"], axis=1).select_dtypes('int64').describe().transpose()
# Out:
#        count       mean         std  min     25%    50%     75%    max
# place  234.0  439.08547  253.295484  4.0  223.00  439.0  659.75  894.0
# rank   234.0  117.50000   67.694165  1.0   59.25  117.5  175.75  234.0

# %% [markdown]
# O esquema acima ajuda a tornar a base de dados mais fácil de usar e de entender, fornecendo uma visão geral da estrutura dos dados.

# %% [markdown]
# **Tratando dados faltantes**

# %%
valores_nulos = paises_df.isnull().values.any()

if valores_nulos:
    print("Há valores nulos na tabela.")
else:
    print("Não há valores nulos na tabela.")
# Out:
# Há valores nulos na tabela.

# %%
valores_nulos = paises_df.isnull().sum()
print(valores_nulos)
# Out:
# place              0
# pop1980            0
# pop2000            0
# pop2010            0
# pop2022            0
# pop2023            0
# pop2030            0
# pop2050            0
# country            0
# area               0
# landAreaKm         0
# cca2               0
# cca3               0
# netChange          8
# growthRate         0
# worldPercentage    6
# density            0
# densityMi          0
# rank               0
# dtype: int64

# %% [markdown]
# **substituindo os valores nulos pela mediana da coluna**

# %%
netChange_median = paises_df.netChange.median()
paises_df.fillna(netChange_median, inplace = True)
paises_df.netChange.isnull().sum()
# Out:
# 0

# %%
worldPercentage_median = paises_df.worldPercentage.median()
paises_df.fillna(worldPercentage_median, inplace = True)
paises_df.worldPercentage.isnull().sum()
# Out:
# 0

# %% [markdown]
# dados atualizados:

# %%
paises_df.head()
# Out:
#    place      pop1980       pop2000       pop2010       pop2022       pop2023  \
# 0    356  696828385.0  1.059634e+09  1.240614e+09  1.417173e+09  1.428628e+09
# 1    156  982372466.0  1.264099e+09  1.348191e+09  1.425887e+09  1.425671e+09
# 2    840  223140018.0  2.823986e+08  3.111828e+08  3.382899e+08  3.399966e+08
# 3    360  148177096.0  2.140724e+08  2.440162e+08  2.755013e+08  2.775341e+08
# 4    586   80624057.0  1.543699e+08  1.944545e+08  2.358249e+08  2.404857e+08
#
#         pop2030       pop2050        country       area  landAreaKm cca2 cca3  \
# 0  1.514994e+09  1.670491e+09          India  3287590.0   2973190.0   IN  IND
# 1  1.415606e+09  1.312636e+09          China  9706961.0   9424702.9   CN  CHN
# 2  3.521623e+08  3.753920e+08  United States  9372610.0   9147420.0   US  USA
# 3  2.921501e+08  3.172252e+08      Indonesia  1904569.0   1877519.0   ID  IDN
# 4  2.740298e+08  3.678085e+08       Pakistan   881912.0    770880.0   PK  PAK
#
# ...

# %% [markdown]
# Acima, verificamos se havia valores nulos. Como havia, tiramos a mediana e a substituímos na tabela.

# %%
paises_df.shape
# Out:
# (234, 19)

# %% [markdown]
# **Separando a base de dados em formatos menores**:

# %% [markdown]
# Como vimos até agora, o conjunto de dados é muito grande, o que dificulta a análise de alguns gráficos. Por isso, foi mais sábio dividi-lo em partes menores. Imagine gerar um gráfico de barras da população com o valor de mais de 200 países! O resultado não seria bom e não seria possível gerar insights.

# %% [markdown]
# **Os dez primeiros países da tabela**:

# %%
top10_paises = paises_df.head(10)
top10_paises.head(10)
# Out:
#    place      pop1980       pop2000       pop2010       pop2022       pop2023  \
# 0    356 696828385.00 1059633675.00 1240613620.00 1417173173.00 1428627663.00
# 1    156 982372466.00 1264099069.00 1348191368.00 1425887337.00 1425671352.00
# 2    840 223140018.00  282398554.00  311182845.00  338289857.00  339996563.00
# 3    360 148177096.00  214072421.00  244016173.00  275501339.00  277534122.00
# 4    586  80624057.00  154369924.00  194454498.00  235824862.00  240485658.00
# 5    566  72951439.00  122851984.00  160952853.00  218541212.00  223804632.00
# 6     76 122288383.00  175873720.00  196353492.00  215313498.00  216422446.00
# 7     50  83929765.00  129193327.00  148391139.00  171186372.00  172954319.00
# 8    643 138257420.00  146844839.00  143242599.00  144713314.00  144444359.00
# 9    484  67705186.00   97873442.00  112532401.00  127504125.00  128455567.00
#
#         pop2030       pop2050        country        area  landAreaKm cca2  \
# ...

# %% [markdown]
# **Os dez últimos países da tabela**:

# %%
top10_ultimos = paises_df.tail(10)
top10_ultimos.tail(20)
# Out:
#      place  pop1980  pop2000  pop2010  pop2022  pop2023  pop2030  pop2050  \
# 224    520  7635.00 10377.00 10241.00 12668.00 12780.00 13358.00 14695.00
# 225    876 11315.00 14723.00 13142.00 11572.00 11502.00 11229.00 11349.00
# 226    798  7731.00  9638.00 10550.00 11312.00 11396.00 11917.00 13211.00
# 227    652  2983.00  7082.00  8988.00 10967.00 10994.00 11113.00 10210.00
# 228    666  6106.00  6274.00  6052.00  5862.00  5840.00  5651.00  5165.00
# 229    500 11452.00  5138.00  4938.00  4390.00  4386.00  4301.00  3781.00
# 230    238  2240.00  3080.00  3187.00  3780.00  3791.00  3869.00  3779.00
# 231    570  3637.00  2074.00  1812.00  1934.00  1935.00  1948.00  2096.00
# 232    772  1647.00  1666.00  1367.00  1871.00  1893.00  2046.00  2430.00
# 233    336   733.00   651.00   596.00   510.00   518.00   561.00   731.00
#
#                        country     area  landAreaKm cca2 cca3  netChange  \
# 224                      Nauru    21.00       20.00   NR  NRU       0.00
# ...

# %% [markdown]
# ### Gráfico de Barras: População Prevista (2023)

# %%
ano2023p = top10_paises[["pop2023","country","pop1980"]].groupby("country").agg("sum").reset_index()
ano2023p.head(10)
# Out:
#          country       pop2023      pop1980
# 0     Bangladesh  172954319.00  83929765.00
# 1         Brazil  216422446.00 122288383.00
# 2          China 1425671352.00 982372466.00
# 3          India 1428627663.00 696828385.00
# 4      Indonesia  277534122.00 148177096.00
# 5         Mexico  128455567.00  67705186.00
# 6        Nigeria  223804632.00  72951439.00
# 7       Pakistan  240485658.00  80624057.00
# 8         Russia  144444359.00 138257420.00
# 9  United States  339996563.00 223140018.00

# %%
ano2023l= top10_ultimos[["pop2023","country"]].groupby("country").agg("sum").reset_index()
ano2023l.head(10)
# Out:
#                      country  pop2023
# 0           Falkland Islands  3791.00
# 1                 Montserrat  4386.00
# 2                      Nauru 12780.00
# 3                       Niue  1935.00
# 4           Saint Barthelemy 10994.00
# 5  Saint Pierre and Miquelon  5840.00
# 6                    Tokelau  1893.00
# 7                     Tuvalu 11396.00
# 8               Vatican City   518.00
# 9          Wallis and Futuna 11502.00

# %%
grafico = sns.barplot(data=ano2023p, x="pop2023",y = "country",errorbar=None, palette="pastel")
grafico.set(title='População em 2023 dos primeiros países',xlabel='Poulação em 2023',ylabel="Países");

# %%
grafico = sns.barplot(data=ano2023l,x="pop2023",y="country",errorbar=None,palette="pastel")
grafico.set(title='População em 2023 dos últimos países',xlabel='Poulação em 2023',ylabel="Países");

# %% [markdown]
# *INSIGHTS:*
#
# 1.   Comparando os dois gráficos acima, podemos notar que a Índia e a China se predominam com as maiores populações do mundo.
# 2.   Podemos notar que há uma diferença enorme na quantidade da população entre os primeiros dez países da lista e os dez últimos.
# 3.   Atualemnte vemos quer o Vaticano é quem possui a menor população mundial seguido, com apenas 2000 habitantes.

# %% [markdown]
# ---

# %% [markdown]
# ### Gráfico de setores: Taxa de crescimento e densidade Mundial por país

# %%
crescimento = top10_paises[["worldPercentage","country"]].groupby("country").agg("sum").reset_index()
total_crescimento = top10_paises["worldPercentage"].sum()
crescimento["percent"] = 100 * crescimento["worldPercentage"] / total_crescimento
crescimento.head(10)
# Out:
#          country  worldPercentage  percent
# 0     Bangladesh             0.02     3.76
# 1         Brazil             0.03     4.70
# 2          China             0.18    31.01
# 3          India             0.18    31.08
# 4      Indonesia             0.03     6.04
# 5         Mexico             0.02     2.79
# 6        Nigeria             0.03     4.87
# 7       Pakistan             0.03     5.22
# 8         Russia             0.02     3.13
# 9  United States             0.04     7.40

# %%
densidade = top10_paises[["density","country"]].groupby("country").agg("sum").reset_index()
total_densidade = top10_paises["density"].sum()
densidade["percent"] = 100 * densidade["density"] / total_densidade
densidade.head(10)
# Out:
#          country  density  percent
# 0     Bangladesh  1328.68    47.39
# 1         Brazil    25.89     0.92
# 2          China   151.27     5.39
# 3          India   480.50    17.14
# 4      Indonesia   147.82     5.27
# 5         Mexico    66.08     2.36
# 6        Nigeria   245.73     8.76
# 7       Pakistan   311.96    11.13
# 8         Russia     8.82     0.31
# 9  United States    37.17     1.33

# %%
crescimento.plot.pie(y="percent",labels=crescimento["country"], autopct='%1.1f%%')
plt.title("Crescimento Populacional")
plt.xlabel("País")
plt.ylabel("Percentual")
plt.show()

# %%
densidade.plot.pie(y="percent",labels=crescimento["country"], autopct='%1.1f%%')
plt.title("Densidade Populacional")
plt.xlabel("País")
plt.ylabel("Percentual")
plt.show()

# %% [markdown]
# *INSIGHTS:*
#
# 1. Observando o primeiro gráfico de setores, podemos notar que a Índia, China e Estados Unidos são os países que possuem a maior taxa de crescimento mundial.
# 2. Observando também o segundo gráfico, vemos que Bangladesh, Índia e Paquistão são os países que têm a maior densidade. A densidade populacional é calculada dividindo a população do país pela sua área.
# 3. Após analisarmos esses dados, notamos que não há tanta influência entre a densidade populacional e a taxa de crescimento global. A Índia é o único país que está em consonância com uma taxa e densidade altas. Bangladesh, por exemplo, possui uma baixa taxa de crescimento, porém uma alta densidade.

# %% [markdown]
# *Observação:* os 10 países acima representam 100% do total de valores só referentes a esses 10 países. Os demais países da tabela paises_df não estão incluídos nesta soma.

# %% [markdown]
# ### Gráfico de Linhas: População por ano e por país

# %%
plt.figure(figsize=(12, 8))

for i in range(len(top10_paises)):
    country_data = top10_paises.iloc[i]
    plt.plot(country_data[['pop1980', 'pop2000', 'pop2010', 'pop2022', 'pop2023', 'pop2030', 'pop2050']], label=country_data['country'])

plt.title('População por Ano e País')
plt.xlabel('Ano')
plt.ylabel('População')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# *Insights:*
#
# 1.   Acima podemos observar que a China teve a maior população de 1980 a 2022. Em 2023, a Índia ultrapassou a China em população, tornando-se o país mais populoso do mundo.

# %% [markdown]
# ### Gráfico de Área: Valor da densidade e da mudança de rede por país

# %%
import matplotlib.pyplot as plt

with sns.axes_style('whitegrid'):

  grafico = sns.FacetGrid(data=top10_paises, palette='pastel')
  grafico.map(sns.lineplot,"country","netChange")
  grafico.map(plt.fill_between, 'country','netChange',alpha=0.3)
  grafico.set(title='Mundança de rede por país',xlabel='Países',ylabel='Mudança de rede(%)');
  grafico.fig.set_size_inches(w=20/1.20,h=9.5/2.54)

# %%
import matplotlib.pyplot as plt

with sns.axes_style('whitegrid'):

  grafico = sns.FacetGrid(data=top10_paises, palette='pastel')
  grafico.map(sns.lineplot,"country","densityMi")
  grafico.map(plt.fill_between, 'country','densityMi',alpha=0.3)
  grafico.set(title='Densidade por milhas quadradas dos países',xlabel='Países',ylabel='Densidade');
  grafico.fig.set_size_inches(w=20/1.20,h=9.5/2.54)

# %% [markdown]
# *INSIGHTS:*
#
# 1.   Observando o primeiro gráfico, vemos que a Índia possui a maior mudança de rede, seguida da Nigéria e do Paquistão.
# 2.   Observando também o segundo gráfico, notamos que Bangladesh possui a maior densidade, seguido da Índia e do Paquistão.

# %% [markdown]
# ### Mapa de calor: População dos últimos dez países

# %%
data = top10_ultimos[["country","pop1980","pop2000","pop2010","pop2022","pop2023","pop2030","pop2050"]]
data.set_index('country', inplace = True)
data.head(20)
# Out:
#                            pop1980  pop2000  pop2010  pop2022  pop2023  \
# country
# Nauru                      7635.00 10377.00 10241.00 12668.00 12780.00
# Wallis and Futuna         11315.00 14723.00 13142.00 11572.00 11502.00
# Tuvalu                     7731.00  9638.00 10550.00 11312.00 11396.00
# Saint Barthelemy           2983.00  7082.00  8988.00 10967.00 10994.00
# Saint Pierre and Miquelon  6106.00  6274.00  6052.00  5862.00  5840.00
# Montserrat                11452.00  5138.00  4938.00  4390.00  4386.00
# Falkland Islands           2240.00  3080.00  3187.00  3780.00  3791.00
# Niue                       3637.00  2074.00  1812.00  1934.00  1935.00
# Tokelau                    1647.00  1666.00  1367.00  1871.00  1893.00
# Vatican City                733.00   651.00   596.00   510.00   518.00
#
#                            pop2030  pop2050
# country
# Nauru                     13358.00 14695.00
# Wallis and Futuna         11229.00 11349.00
# ...

# %%
grafico = sns.heatmap(data=data, cmap="Spectral")
grafico.set(title='População dos últimos dez países de 1980 a 2050', xlabel='Ano', ylabel='Mês');

# %% [markdown]
# *INSIGHTS:*
#
#
# 1.   Observamos que desde o ano de 1980 o Vaticano tem sido o país com a menor população mundial.

# %% [markdown]
# ### gráfico de dispersão: Taxa de crescimento

# %%
df = pd.DataFrame(paises_df)

plt.scatter(df['rank'], df['growthRate'], c=df['pop2023'], cmap='viridis')
plt.xlabel('Rank')
plt.ylabel('Taxa de Crescimento')
plt.title('Gráfico de Dispersão: Rank vs Taxa de Crescimento')
plt.colorbar(label='Ano de 2023')
plt.show()

# %%
df = pd.DataFrame(paises_df)

plt.scatter(df['rank'], df['growthRate'], c=df['pop2030'], cmap='viridis')
plt.xlabel('Rank')
plt.ylabel('Taxa de Crescimento')
plt.title('Gráfico de Dispersão: Rank vs Taxa de Crescimento')
plt.colorbar(label='Ano de 2030')
plt.show()

# %%
df = pd.DataFrame(paises_df)

plt.scatter(df['rank'], df['growthRate'], c=df['pop2050'], cmap='viridis')
plt.xlabel('Rank')
plt.ylabel('Taxa de Crescimento')
plt.title('Gráfico de Dispersão: Rank vs Taxa de Crescimento')
plt.colorbar(label='Ano de 2050')
plt.show()

# %% [markdown]
# *Insights:*
#
#
# 1.   Comparando a taxa de crescimento dos três gráficos vemos que os valores se mantem constantes ao longo dos anos.

# %% [markdown]
# ### Tabela: Valores únicos de cada país

# %%
valores_unicos = paises_df[['country','cca2','cca3']]
valores_unicos = valores_unicos.rename(columns={'cca2':'valores_unicos1','cca3':'valores_unicos2'})
valores_unicos.head(10)
# Out:
#          country valores_unicos1 valores_unicos2
# 0          India              IN             IND
# 1          China              CN             CHN
# 2  United States              US             USA
# 3      Indonesia              ID             IDN
# 4       Pakistan              PK             PAK
# 5        Nigeria              NG             NGA
# 6         Brazil              BR             BRA
# 7     Bangladesh              BD             BGD
# 8         Russia              RU             RUS
# 9         Mexico              MX             MEX

# %% [markdown]
# ### valores categóricos e Visualização com Box Plot

# %% [markdown]
# **População em 2023 dos países**

# %%
paises_df['pop2023'].describe().T
# Out:
# count    2.340000e+02
# mean     3.437442e+07
# std      1.373864e+08
# min      5.180000e+02
# 25%      4.225982e+05
# 50%      5.643895e+06
# 75%      2.324537e+07
# max      1.428628e+09
# Name: pop2023, dtype: float64

# %%
paises_df["pop2023_valor"] = np.where(paises_df['pop2023']> 5.643895e+06, 'Alta população','Baixa população')

# %%
data = paises_df[["rank","pop2023","pop2023_valor"]]
data.head()
# Out:
#    rank       pop2023   pop2023_valor
# 0     1  1.428628e+09  Alta população
# 1     2  1.425671e+09  Alta população
# 2     3  3.399966e+08  Alta população
# 3     4  2.775341e+08  Alta população
# 4     5  2.404857e+08  Alta população

# %%
data.tail()
# Out:
#      rank  pop2023    pop2023_valor
# 229   230   4386.0  Baixa população
# 230   231   3791.0  Baixa população
# 231   232   1935.0  Baixa população
# 232   233   1893.0  Baixa população
# 233   234    518.0  Baixa população

# %% [markdown]
# Quantidade de valores de acordo com a classificação da população em 2023:

# %%
counts = data["pop2023_valor"].value_counts()
counts.head()
# Out:
# Alta população     117
# Baixa população    117
# Name: pop2023_valor, dtype: int64

# %% [markdown]
# Visualizando os valores utilizando o Box Plot:

# %%
with sns.axes_style('whitegrid'):

  grafico = sns.boxplot(x=data["rank"],y=data["pop2023_valor"])
  grafico.set(title='Distribuição da população 2023', xlabel='rank',ylabel="população 2023");

# %% [markdown]
# *INSIGHTS:*
#
#
#
# 1.   Observando o gráfico acima, vemos o que já era esperado dos dados, os primeiros valores do rank são os que possuem as maiores populações, enquanto os últimos as menores.

# %% [markdown]
# **Área dos países**

# %%
paises_df['area'].describe().T
# Out:
# count    2.340000e+02
# mean     5.814500e+05
# std      1.761841e+06
# min      4.400000e-01
# 25%      2.650000e+03
# 50%      8.119950e+04
# 75%      4.304258e+05
# max      1.709824e+07
# Name: area, dtype: float64

# %% [markdown]
# Vamos dividir a área em duas categorias, os que representam uma grande area e os que represtam uma pequena area.

# %%
paises_df["Area_valor"] = np.where(paises_df['area']> 8.119950e+04, 'Grande Area','Pequena Area')

# %%
data2 = paises_df[['rank','area','Area_valor']]
data2.head()
# Out:
#    rank       area   Area_valor
# 0     1  3287590.0  Grande Area
# 1     2  9706961.0  Grande Area
# 2     3  9372610.0  Grande Area
# 3     4  1904569.0  Grande Area
# 4     5   881912.0  Grande Area

# %%
data2.tail()
# Out:
#      rank      area    Area_valor
# 229   230    102.00  Pequena Area
# 230   231  12173.00  Pequena Area
# 231   232    261.00  Pequena Area
# 232   233     12.00  Pequena Area
# 233   234      0.44  Pequena Area

# %% [markdown]
# Quantidade de valores de acordo com a classificação da área:

# %%
counts2 = data2["Area_valor"].value_counts()
counts2.head()
# Out:
# Grande Area     117
# Pequena Area    117
# Name: Area_valor, dtype: int64

# %% [markdown]
# Visualizando os valores utilizando Box Plot:

# %%
with sns.axes_style('whitegrid'):

  grafico = sns.scatterplot(data=data2, x="rank", y="area", hue="Area_valor", palette="pastel")
  grafico.set(title='Area dos países por grande e pequena', xlabel='rank', ylabel='Area');
  grafico.get_legend().set_title("Tamanho da Area");

# %% [markdown]
# *INSIGHTS:*
#
#
# 1.   Observando o gráfico vemos que os 50 primeiros países do rank possuem uma grande área.
# 2.   Vemos também que países podem possui uma grande área, mas uma baixa população.
# 3.   Notamos que do rank 150 até o final a maior parte possui uma baixa area.

# %% [markdown]
# ### Mapa: Países da América do Sul

# %%
south_american_countries = paises_df[paises_df['country'].isin(['Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Ecuador', 'Guyana', 'Paraguay', 'Peru', 'Suriname', 'Uruguay', 'Venezuela'])]

# %%
data3 = south_american_countries[['country','pop2022']]
data3.head(20)
# Out:
#        country      pop2022
# 6       Brazil  215313498.0
# 27    Colombia   51874024.0
# 32   Argentina   45510318.0
# 44        Peru   34049588.0
# 51   Venezuela   28301696.0
# 64       Chile   19603733.0
# 67     Ecuador   18001000.0
# 79     Bolivia   12224110.0
# 107   Paraguay    6780744.0
# 134    Uruguay    3422794.0
# 163     Guyana     808726.0
# 169   Suriname     618040.0

# %%
fig = px.choropleth(data3,
                    locations='country',
                    locationmode='country names',
                    color='pop2022',
                    hover_name='country',
                    title = '2022 Population',
                    color_continuous_scale='Viridis'
                    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# *INSIGHTS:*
#
#
# 1.   Podemos observar que dos países da América do Sul o Brasil é o que possui a maior população, sendo o único a está no nível amarelo.

# %% [markdown]
# ## 2ª CONJUNTO DE DADOS (América do Sul)

# %%
display(Image(url='https://1.bp.blogspot.com/-FM-BUiA3KSk/Vhq0mtwPVwI/AAAAAAAAAQ8/P3pkb9ywJno/s1600/Am%25C3%25A9rica%2Bdo%2BSul.jpg',width=700))
# Out:
# <img src="https://1.bp.blogspot.com/-FM-BUiA3KSk/Vhq0mtwPVwI/AAAAAAAAAQ8/P3pkb9ywJno/s1600/Am%25C3%25A9rica%2Bdo%2BSul.jpg" width="700"/>

# %% [markdown]
# ### Preparando os dados para o projeto:

# %% [markdown]
# **Importando os dados**

# %%
dados = pd.read_excel('DadosSocioeconomicoPaises (2).xlsx')
dados.head(20)
# Out:
#          País PIB(bi R$) Taxa de endividamento  Taxa de desemprego  \
# 0      Brazil   1.920,10               92,34 %               0.095
# 1    Colombia     343,94               64,60 %               0.107
# 2   Argentina     632,77               80,93 %               0.065
# 3        Peru     242,63               33,70 %               0.037
# 4   Venezuela     482,36              240,52 %               0.053
# 5       Chile     301,03               36,29 %               0.078
# 6     Ecuador     115,05               49,84 %               0.040
# 7     Bolivia      43,07               62,73 %               0.044
# 8    Paraguay      41,72               31,62 %               0.069
# 9     Uruguay      71,18               57,38 %               0.078
# 10     Guyana      15,36               42,90 %               0.124
# 11   Suriname       3,62              125,70 %               0.086
#
#    Taxa de inflação  Índice de corrupção
# 0            9,28 %                   38
# ...

# %% [markdown]
# **Conhecendo a estrutura dos dados**

# %%
dados.shape
# Out:
# (12, 6)

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   País                   12 non-null     object
#  1   PIB(bi R$)             12 non-null     object
#  2   Taxa de endividamento  12 non-null     object
#  3   Taxa de desemprego     12 non-null     float64
#  4   Taxa de inflação       12 non-null     object
#  5   Índice de corrupção    12 non-null     int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 704.0+ bytes

# %%
dados.columns
# Out:
# Index(['País', 'PIB(bi R$)', 'Taxa de endividamento', 'Taxa de desemprego',
#        'Taxa de inflação', 'Índice de corrupção'],
#       dtype='object')

# %% [markdown]
# **SCHEMA**

# %% [markdown]
# Atributos categóricos:

# %%
dados.select_dtypes("object").describe().transpose()
# Out:
#                       count unique       top freq
# País                     12     12    Brazil    1
# PIB(bi R$)               12     12  1.920,10    1
# Taxa de endividamento    12     12   92,34 %    1
# Taxa de inflação         12     12    9,28 %    1

# %% [markdown]
# Atributos numéricos:

# %%
dados.drop(["País","PIB(bi R$)","Taxa de endividamento","Taxa de inflação"], axis=1).select_dtypes('int64').describe().transpose()
# Out:
#                      count       mean        std   min    25%   50%   75%  \
# Índice de corrupção   12.0  40.083333  16.030983  14.0  34.75  38.0  40.0
#
#                       max
# Índice de corrupção  74.0

# %% [markdown]
# **Verificando a presença de valores nulos**

# %%
valores_nulos = dados.isnull().values.any()

if valores_nulos:
    print("Há valores nulos na tabela.")
else:
    print("Não há valores nulos na tabela.")
# Out:
# Não há valores nulos na tabela.

# %%
valores_nulos = dados.isnull().sum()
print(valores_nulos)
# Out:
# País                     0
# PIB(bi R$)               0
# Taxa de endividamento    0
# Taxa de desemprego       0
# Taxa de inflação         0
# Índice de corrupção      0
# dtype: int64

# %% [markdown]
# Acima, observamos que nossa tabela não possui valores nulos e também já conhecemos os dados com o qual vamos trabalhar.

# %% [markdown]
# ### Visualizando Os Dados Em Um Mapa Geográfico

# %%
fig = px.choropleth(dados,
                    locations='País',
                    locationmode='country names',
                    color='PIB(bi R$)',
                    hover_name='País',
                    title = 'PIB País',
                    color_continuous_scale='Viridis'
                    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.choropleth(dados,
                    locations='País',
                    locationmode='country names',
                    color='Taxa de endividamento',
                    hover_name='País',
                    title = 'Taxa de endividamento',
                    color_continuous_scale='Viridis'
                    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.choropleth(dados,
                    locations='País',
                    locationmode='country names',
                    color='Taxa de desemprego',
                    hover_name='País',
                    title = 'Taxa de desemprego',
                    color_continuous_scale='Viridis'
                    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.choropleth(dados,
                    locations='País',
                    locationmode='country names',
                    color='Taxa de inflação',
                    hover_name='País',
                    title = 'Taxa de inflação',
                    color_continuous_scale='Viridis'
                    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.choropleth(dados,
                    locations='País',
                    locationmode='country names',
                    color='Índice de corrupção',
                    hover_name='País',
                    title = 'Índice de corrupção',
                    color_continuous_scale='Viridis'
                    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# *INSIGHTS:*
#
#
# 1.   No primeiro mapa vemos que o Brasil é o país que possui um alto PIB em relação aos demais, levando em conta que possui a maior população também, o que pode contribuir para isso.
# 2.   No segundo mapa vemos que a Venezuela possui a maior taxa de endividamento, chegando até valores preocupantes, apesar de ter o 2° maior PIB da América do Sul.
# 3.   No terceiro mapa vemos que a Guiana é o país que apresenta a maior taxa de desemprego, podemos levar em conta o fato de possuirem um dos piores PIBs da lista de países.
# 4.   No quarto mapa vemos que a Venezuela é o país que possui a maior taxa de inflação, chegando até um valor extremamente alto, isso se deve provavelmente por possui a maior taxa de endividamento. Enquanto isso a Bolívia é o país que possui a menor taxa de inflação, consideravelmente baixa.
# 5.   No quinto mapa vemos que a venezuela possui um índice de corrupção muito ruim, enquanto Chile e Uruguay apresentam bons índices.

# %% [markdown]
# ## 3ª CONJUNTO DE DADOS (Brasil)

# %% [markdown]
# Os dados para essa parte do projeto foram minerados de uma tabela HTML em um site da web. Nem todos os sites permitem esse tipo de extração de dados, portanto é importante verificar o arquivo robots.txt do site para verificar se ele permite esse tipo de análise. Se não, você pode ser bloqueado do site. O seguinte link: https://en.wikipedia.org/robots.txt nos leva ao arquivo robots.txt do site utilizado nesse projeto.

# %%
display(Image(url='https://st.depositphotos.com/1018414/2467/i/450/depositphotos_24676175-stock-photo-night-earth-a-piece-of.jpg',width=700))
# Out:
# <img src="https://st.depositphotos.com/1018414/2467/i/450/depositphotos_24676175-stock-photo-night-earth-a-piece-of.jpg" width="700"/>

# %% [markdown]
# ### Preparando os dados para o projeto:

# %%
url= 'https://pt.wikipedia.org/wiki/Demografia_do_Brasil'

# %%
html = pd.read_html(url, match='Região')

# %%
regiao_brasil = html[0]

# %%
regiao_brasil
# Out:
#          Região                                            Estados Municípios  \
# 0         Norte  Acre  Amapá  Amazonas  Pará  Rondônia  Roraima...        450
# 1      Nordeste  Alagoas  Bahia  Ceará  Maranhão  Paraíba  Pern...      1 793
# 2  Centro-Oeste  Distrito Federal  Goiás  Mato Grosso  Mato Gro...        467
# 3       Sudeste  Espírito Santo  Minas Gerais  Rio de Janeiro  ...      1 668
# 4           Sul          Paraná  Santa Catarina  Rio Grande do Sul      1 191
# 5        Brasil                           26 e um distrito federal      5 570
#
#   População (2022)[5]            %
# 0          17 349 619          NaN
# 1          54 644 582          NaN
# 2          16 287 809          NaN
# 3          84 847 187          NaN
# 4          29 933 315          NaN
# 5         203 062 512  203 062 512

# %% [markdown]
# Vamos selecionar apenas os dados que vamos utilizar para realizar as análises.

# %%
brasil = regiao_brasil[["Região","Estados","Municípios","População (2022)[5]"]].head(5)

# %%
brasil.head(10)
# Out:
#          Região                                            Estados Municípios  \
# 0         Norte  Acre  Amapá  Amazonas  Pará  Rondônia  Roraima...        450
# 1      Nordeste  Alagoas  Bahia  Ceará  Maranhão  Paraíba  Pern...      1 793
# 2  Centro-Oeste  Distrito Federal  Goiás  Mato Grosso  Mato Gro...        467
# 3       Sudeste  Espírito Santo  Minas Gerais  Rio de Janeiro  ...      1 668
# 4           Sul          Paraná  Santa Catarina  Rio Grande do Sul      1 191
#
#   População (2022)[5]
# 0          17 349 619
# 1          54 644 582
# 2          16 287 809
# 3          84 847 187
# 4          29 933 315

# %% [markdown]
# **Agora vamos entender a estrutura dos dados**

# %%
brasil.shape
# Out:
# (5, 4)

# %%
brasil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Região               5 non-null      object
#  1   Estados              5 non-null      object
#  2   Municípios           5 non-null      object
#  3   População (2022)[5]  5 non-null      object
# dtypes: object(4)
# memory usage: 288.0+ bytes

# %% [markdown]
# **SCHEMA**

# %% [markdown]
# Atributos categóricos:

# %%
brasil.select_dtypes("object").describe().transpose()
# Out:
#                     count unique  \
# Região                  5      5
# Estados                 5      5
# Municípios              5      5
# População (2022)[5]     5      5
#
#                                                                    top freq
# Região                                                           Norte    1
# Estados              Acre  Amapá  Amazonas  Pará  Rondônia  Roraima...    1
# Municípios                                                         450    1
# População (2022)[5]                                         17 349 619    1

# %% [markdown]
# **Agora vamos verificar se os dados possuem valores nulos**

# %%
valores_nulos = dados.isnull().values.any()

if valores_nulos:
    print("Há valores nulos na tabela.")
else:
    print("Não há valores nulos na tabela.")
# Out:
# Não há valores nulos na tabela.

# %%
valores_nulos = dados.isnull().sum()
print(valores_nulos)
# Out:
# País                     0
# PIB(bi R$)               0
# Taxa de endividamento    0
# Taxa de desemprego       0
# Taxa de inflação         0
# Índice de corrupção      0
# dtype: int64

# %% [markdown]
# Acima vemos que os dados não possuem valores nulos, no entanto, os dados não estão no formato desejado para realizar as análises.

# %% [markdown]
# **TRATANDO OS VALORES PARA O FORMATO CORRETO:**

# %% [markdown]
# O Conjunto de dados trouxe todos os valores no formato "string" o que dificulta a formação dos gráficos pois as colunas "Municípios" e "População (2022)[5]"  não estão no formato de número, então temos que converte-las.

# %% [markdown]
# *   População (2022)[5]

# %%
brasil["População (2022)[5]"] = brasil["População (2022)[5]"].str.replace(" ", "")

# %%
brasil["População (2022)[5]"] = brasil["População (2022)[5]"].str.replace("\xa0", "")

# %%
brasil["População (2022)[5]"] = brasil["População (2022)[5]"].astype(float)

# %% [markdown]
# *   Municípios

# %%
brasil["Municípios"] = brasil["Municípios"].str.replace(" ","")

# %%
brasil["Municípios"] = brasil["Municípios"].str.replace("\xa0","")

# %%
brasil["Municípios"] = brasil["Municípios"].astype(float)

# %% [markdown]
# Agora podemos verificar o tipo de dados depois da transformação:

# %%
brasil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Região               5 non-null      object
#  1   Estados              5 non-null      object
#  2   Municípios           5 non-null      float64
#  3   População (2022)[5]  5 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 288.0+ bytes

# %% [markdown]
# ### Gráfico de Bolhas: População por Região brasileira

# %%
df = brasil

fig = px.scatter(df, x="População (2022)[5]", y="Municípios",
	         size="População (2022)[5]", color="Região",
                 hover_name="Municípios", log_x=True, size_max=100)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# *INSIGHTS:*
#
# 1.   Comparando os dados do gráfico vemos que o Sudeste é a região que teve o maior valor de população em 2022.
# 2.   No segundo lugar de maior população em 2022 ficou o Nordeste, que possui a maior quantidade de municípios, seguido do Sul em terceiro.
# 3.   Agora, por fim, notamos que em penúltimo e último lugar, respectivamente, estão as regiões Norte e Centro-Oeste.

# %% [markdown]
# ## 4ª CONJUNTO DE DADOS (Grupo de Países)

# %%
display(Image(url='https://opinioescertificadas.com.br/wp-content/uploads/2021/07/globo-terrestre-capa.jpg',width=900))
# Out:
# <img src="https://opinioescertificadas.com.br/wp-content/uploads/2021/07/globo-terrestre-capa.jpg" width="900"/>

# %% [markdown]
# ### Preparando os dados para o projeto:

# %%
html2 = pd.read_html(url, match='Crianças')

# %%
faixa_etaria = html2[0]

# %%
faixa_etaria
# Out:
#           País Crianças (de 0 a 14 anos) Jovens (de 15 a 24 anos)  \
# 0       Brasil                     20,0%                    15,7%
# 1  Reino Unido                     17,1%                    11,8%
# 2       México                     24,3%                    17,0%
# 3      Nigéria                     41,0%                    20,6%
#
#   Adultos (de 25 a 64 anos) Idosos (a partir de 65 anos)
# 0                     54,1%                        10,2%
# 1                     52,3%                        18,8%
# 2                     50,8%                         7,9%
# 3                     35,3%                         3,1%

# %% [markdown]
# Vamos conhecer melhor os dados

# %%
faixa_etaria.shape
# Out:
# (4, 5)

# %%
faixa_etaria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   País                          4 non-null      object
#  1   Crianças (de 0 a 14 anos)     4 non-null      object
#  2   Jovens (de 15 a 24 anos)      4 non-null      object
#  3   Adultos (de 25 a 64 anos)     4 non-null      object
#  4   Idosos (a partir de 65 anos)  4 non-null      object
# dtypes: object(5)
# memory usage: 288.0+ bytes

# %%
faixa_etaria.columns
# Out:
# Index(['País', 'Crianças (de 0 a 14 anos)', 'Jovens (de 15 a 24 anos)',
#        'Adultos (de 25 a 64 anos)', 'Idosos (a partir de 65 anos)'],
#       dtype='object')

# %% [markdown]
# **SCHEMA**

# %% [markdown]
# Atributos categóricos:

# %%
faixa_etaria.select_dtypes("object").describe().transpose()
# Out:
#                              count unique     top freq
# País                             4      4  Brasil    1
# Crianças (de 0 a 14 anos)        4      4   20,0%    1
# Jovens (de 15 a 24 anos)         4      4   15,7%    1
# Adultos (de 25 a 64 anos)        4      4   54,1%    1
# Idosos (a partir de 65 anos)     4      4   10,2%    1

# %% [markdown]
# **Vamos verificar se os dados possuem valores nulos**

# %%
valores_nulos = faixa_etaria.isnull().values.any()

if valores_nulos:
    print("Há valores nulos na tabela.")
else:
    print("Não há valores nulos na tabela.")
# Out:
# Não há valores nulos na tabela.

# %%
valores_nulos = faixa_etaria.isnull().sum()
print(valores_nulos)
# Out:
# País                            0
# Crianças (de 0 a 14 anos)       0
# Jovens (de 15 a 24 anos)        0
# Adultos (de 25 a 64 anos)       0
# Idosos (a partir de 65 anos)    0
# dtype: int64

# %% [markdown]
# Acima podemos ver que os dados não possuem valores nulos, no entanto, como no conjunto de dados anterior, temos que tranformar os dados para o formato correto para realizar nossas análises

# %% [markdown]
# **TRATANDO OS VALORES PARA O FORMATO CORRETO**

# %% [markdown]
# *   Crianças (de 0 a 14 anos)

# %%
faixa_etaria["Crianças (de 0 a 14 anos)"] = faixa_etaria["Crianças (de 0 a 14 anos)"].str.replace("%", "")

# %%
faixa_etaria["Crianças (de 0 a 14 anos)"] = faixa_etaria["Crianças (de 0 a 14 anos)"].str.replace(",", "")

# %%
faixa_etaria["Crianças (de 0 a 14 anos)"] = faixa_etaria["Crianças (de 0 a 14 anos)"].astype(float)

# %% [markdown]
# *   Jovens (de 15 a 24 anos)

# %%
faixa_etaria["Jovens (de 15 a 24 anos)"] = faixa_etaria["Jovens (de 15 a 24 anos)"].str.replace("%", "")

# %%
faixa_etaria["Jovens (de 15 a 24 anos)"] = faixa_etaria["Jovens (de 15 a 24 anos)"].str.replace(",", "")

# %%
faixa_etaria["Jovens (de 15 a 24 anos)"] = faixa_etaria["Jovens (de 15 a 24 anos)"].astype(float)

# %% [markdown]
# *   Adultos (de 25 a 64 anos)

# %%
faixa_etaria["Adultos (de 25 a 64 anos)"] = faixa_etaria["Adultos (de 25 a 64 anos)"].str.replace("%", "")

# %%
faixa_etaria["Adultos (de 25 a 64 anos)"] = faixa_etaria["Adultos (de 25 a 64 anos)"].str.replace(",", "")

# %%
faixa_etaria["Adultos (de 25 a 64 anos)"] = faixa_etaria["Adultos (de 25 a 64 anos)"].astype(float)

# %% [markdown]
# *   Idosos (a partir de 65 anos)

# %%
faixa_etaria["Idosos (a partir de 65 anos)"] = faixa_etaria["Idosos (a partir de 65 anos)"].str.replace("%", "")

# %%
faixa_etaria["Idosos (a partir de 65 anos)"] = faixa_etaria["Idosos (a partir de 65 anos)"].str.replace(",", "")

# %%
faixa_etaria["Idosos (a partir de 65 anos)"] = faixa_etaria["Idosos (a partir de 65 anos)"].astype(float)

# %% [markdown]
# Agora vamos verificar o tipo dos dados depois da transformação:

# %%
faixa_etaria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   País                          4 non-null      object
#  1   Crianças (de 0 a 14 anos)     4 non-null      float64
#  2   Jovens (de 15 a 24 anos)      4 non-null      float64
#  3   Adultos (de 25 a 64 anos)     4 non-null      float64
#  4   Idosos (a partir de 65 anos)  4 non-null      float64
# dtypes: float64(4), object(1)
# memory usage: 288.0+ bytes

# %% [markdown]
# ### Gráfico de Setores: Distribuição da Faixa Etária

# %%
fig = px.pie(faixa_etaria, values='Crianças (de 0 a 14 anos)', names='País')
fig.update_layout(title_text='Distribuição por faixa etária: Crianças (de 0 a 14 anos)')
fig.show()

fig2 = px.pie(faixa_etaria, values='Jovens (de 15 a 24 anos)', names='País')
fig2.update_layout(title_text='Distribuição por faixa etária: Jovens (de 15 a 24 anos)')
fig2.show()

fig3 = px.pie(faixa_etaria, values='Adultos (de 25 a 64 anos)', names='País')
fig3.update_layout(title_text='Distribuição por faixa etária: Adultos (de 25 a 64 anos)')
fig3.show()

fig4 = px.pie(faixa_etaria, values='Idosos (a partir de 65 anos)', names='País')
fig4.update_layout(title_text='Distribuição por faixa etária: Idosos (a partir de 65 anos) ')
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# *INSIGHTS:*
#
# 1.   Comparando os dados do gráfico vemos que a Nigéria é o país que possui a maior taxa da população de crianças e de jovens, seguido do México, Brasil e Reino Unido.
# 2.   Já no quesito de quem possui a maior taxa de população de adultos, o Brasil está em primeiro lugar, seguido do Reino Unido, México e Nigéria.
# 3.   Agora, por fim, observamos que o Reino Unido é o país que possui a maior taxa de população idosa, chegando quase a 50%, seguido do Brasil, México e Nigéria.

# %% [markdown]
# ## Relatório no Power BI

# %% [markdown]
#  Segue abaixo a tabela referente ao banco de imagens que utilizei para carregar as imagens dos infográficos referentes as informações dos países da América do Sul, que eu criei na plataforma do canvas. E logo depois, temos o link do relatório no power BI em que trabalhei com o 1ª, 2ª conjunto de dados e o conjunto de dados de imagens, que traz informações sobre todos os países e os países da América do Sul.

# %%
imagens = pd.read_excel('America_sul_imagens.xlsx')
imagens.head(12)
# Out:
#        Brazil  \
# 0    Colombia
# 1   Argentina
# 2        Peru
# 3   Venezuela
# 4       Chile
# 5     Ecuador
# 6     Bolivia
# 7    Paraguay
# 8     Uruguay
# 9      Guyana
# 10   Suriname
#
#    https://i.pinimg.com/736x/c8/d1/93/c8d19328f866a605fbfcbdaaa0aabe31.jpg
# 0   https://i.pinimg.com/736x/09/d0/f8/09d0f87d592...
# 1   https://i.pinimg.com/736x/31/ed/9f/31ed9f60f66...
# 2   https://i.pinimg.com/736x/1a/12/c4/1a12c492a3d...
# 3   https://i.pinimg.com/736x/e6/6a/50/e66a50061f5...
# 4   https://i.pinimg.com/736x/70/4f/ad/704fad0605d...
# 5   https://i.pinimg.com/736x/76/5d/92/765d92097ea...
# 6   https://i.pinimg.com/736x/25/9d/25/259d25364d1...
# 7   https://i.pinimg.com/736x/da/83/49/da8349b1120...
# 8   https://i.pinimg.com/736x/4c/f7/8d/4cf78d83ff0...
# 9   https://i.pinimg.com/736x/5a/c4/f4/5ac4f41db18...
# 10  https://i.pinimg.com/736x/07/b0/a0/07b0a0881f7...

# %% [markdown]
# Link do relatório: https://bit.ly/MicaelLimaAnalistaDeDadosRelatorioPopulacao

# %% [markdown]
# ## Conclusão

# %% [markdown]
# * Trabalhamos com diferentes banco de dados.
# * Identificamos problemas que os dados podem causar se não forem tratados corretamente.
# * Vimos o passo a passo de como preparar os dados para a execução das atividades.
# * Aprendemos que cada tipo de dado pode ter uma visulização gráfica ideal para gerar insights significativos.
# * Geramos diversos tipos de gráficos para visualizar melhor os dados e tirar diversas conclusões sobre eles.
# * Comparamos as informações dos dados para chegar a algumas conclusões.
# * Pudemos ver a ordem cronológica das informações e suas variações.
# * Manipulamos dados e dividimos em valores categóricos.
# * Analisamos a situação socioeconômica de diferentes países.
# * Exploramos dados de tabelas html e analisamos os dados em gráficos interativos.

# %% [markdown]
# ## Referências

# %% [markdown]
# * https://ebaconline.com.br/
# * https://plotly.com/graphing-libraries/
# * https://www.kaggle.com/
